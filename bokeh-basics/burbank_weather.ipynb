# %%
import numpy as np
import pandas as pd

# %%
# !gunzip data/weather_19580901_20180809.csv.gz

# %%
df_weather = pd.read_csv('data/weather_19580901_20180809.csv', parse_dates=True, index_col='DATE', sep=',', low_memory=False)

# %%
df_weather.head()
# Out:
#                         STATION                             STATION_NAME  \
# DATE
# 1958-09-01 01:00:00  WBAN:23152  BURBANK GLENDALE PASADENA AIRPORT CA US
# 1958-09-01 02:00:00  WBAN:23152  BURBANK GLENDALE PASADENA AIRPORT CA US
# 1958-09-01 03:00:00  WBAN:23152  BURBANK GLENDALE PASADENA AIRPORT CA US
# 1958-09-01 04:00:00  WBAN:23152  BURBANK GLENDALE PASADENA AIRPORT CA US
# 1958-09-01 05:00:00  WBAN:23152  BURBANK GLENDALE PASADENA AIRPORT CA US
#
#                      ELEVATION  LATITUDE  LONGITUDE REPORTTPYE  \
# DATE
# 1958-09-01 01:00:00      225.9  34.20056  -118.3575        SAO
# 1958-09-01 02:00:00      225.9  34.20056  -118.3575        SAO
# 1958-09-01 03:00:00      225.9  34.20056  -118.3575        SAO
# 1958-09-01 04:00:00      225.9  34.20056  -118.3575        SAO
# 1958-09-01 05:00:00      225.9  34.20056  -118.3575        SAO
#
#                     HOURLYSKYCONDITIONS HOURLYVISIBILITY  \
# DATE
# 1958-09-01 01:00:00                 NaN              NaN
# ...

# %%
df_weather[['HOURLYDRYBULBTEMPF']].describe()
# Out:
#        HOURLYDRYBULBTEMPF
# count              439891
# unique                156
# top                    63
# freq                17948
